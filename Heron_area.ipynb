# %% [markdown]
# <a href="https://colab.research.google.com/github/davidiglesias31/digilizacion/blob/main/Heron_area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cálculo del área de un triángulo
# Usando la fórmula de Herón, calculamos el área de cualquier triángulo conociendo la longitud de sus tres lados. Debes escribir un programa que te pida los tres lados y que calcule el área.
#
#
# > Cálculo del semiperímetro: $s = \frac{a+b+c}{2}$
#
# > Cálculo del área: $área = \sqrt{s(s-a)(s-b)(s-c)}$

# %%
#Pedimos el valor entero de cada uno de los lados
ladoA = int(input("lado 1:"))
ladoB = int(input("lado 2:"))
ladoC = int(input("lado 3:"))

#Cálculo del semiperímetro
semiperimetro = (ladoA+ladoB+ladoC)/2
print("Semiparametro:", semiperimetro)

#Cálculo del área
resultado = (semiperimetro*(semiperimetro-ladoA)*(semiperimetro-ladoB)*(semiperimetro-ladoC))**(1/2)


#Imprimimos el resultado
print("El área del triángulo es:", resultado)
# Out:
# lado 1:2
# lado 2:2
# lado 3:2
# Semiparametro: 3.0
# El área del triángulo es: 1.7320508075688772
